# %% [markdown]
# Import libraries

# %%
import gym

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

env = gym.make("CartPole-v1")

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)

vec_env = model.get_env()

vec_env.reset()

# Evaluate the trained model over 100 episodes
mean_reward, std_reward = evaluate_policy(model, vec_env, n_eval_episodes=100)
print(f'Mean reward: {mean_reward} +/- {std_reward:.2f}')
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.8     |
# |    ep_rew_mean     | 24.8     |
# | time/              |          |
# |    fps             | 1933     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.5        |
# |    ep_rew_mean          | 29.5        |
# | time/                   |             |
# |    fps                  | 1505        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007853358 |
# |    clip_fraction        | 0.0882      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.00935     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.8         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 58.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.1       |
# |    ep_rew_mean          | 37.1       |
# | time/                   |            |
# |    fps                  | 1407       |
# |    iterations           | 3          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00955636 |
# |    clip_fraction        | 0.0567     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.673     |
# |    explained_variance   | 0.0548     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.2       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0155    |
# |    value_loss           | 43         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47.9         |
# |    ep_rew_mean          | 47.9         |
# | time/                   |              |
# |    fps                  | 1339         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0097984765 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.64        |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.6         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0234      |
# |    value_loss           | 52.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.2        |
# |    ep_rew_mean          | 59.2        |
# | time/                   |             |
# |    fps                  | 1315        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008889884 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.31        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 63.4        |
# -----------------------------------------
# Mean reward: 367.67 +/- 128.16
